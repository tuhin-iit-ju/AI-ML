# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Admin\OneDrive\Desktop\Machine learning\venv\Scripts\python.exe

# %%
print("hello")
# Out:
# hello

# %%
a = input()
a= int(a)
print(a* a)
# Out:
#  6
# 36
